# %% [markdown]
# # Introduction
#
# Being a Data Scientist many questions arises in our mind and those questions are what drives us to get some insightful answers. One such question is: Does the people who live longer in rich countries like USA, China live longer? With this in our mind we decided to create a project __Life Expectancy & GDP__.
#
# For this project, we will analyze data on GDP and life expectancy from the World Health Organization and the World Bank to try and identify the relationship between the GDP and life expectancy of six countries.
#
# # Import Required Libraries
# Let us start this project by importing the required libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

sns.set()

# %% [markdown]
# ## Exploratory Data Analysis
#
# We start with __Initial Data Inspection__ by loading the data and printing the first five rows to get the idea to ensure that the data is loaded properly and observe the columns and data values to get the idea of what we are dealing with.

# %%
life_expectancy_and_gdp = pd.read_csv("all_data.csv")
life_expectancy_and_gdp.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %% [markdown]
# Observing the rows, we say that the values are as expected as of Columns.
#
# Now to get some __Data Information__ we ask questions like:
# 1. How many rows are present?
# 2. How many Null Observations we have?
# 3. How many unique columns we have and what are their names?
# 4. What are the data type of each Column?

# %%
life_expectancy_and_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB

# %%
life_expectancy_and_gdp['Country'].unique()
# Out:
# array(['Chile', 'China', 'Germany', 'Mexico', 'United States of America',
#        'Zimbabwe'], dtype=object)

# %%
life_expectancy_and_gdp['Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015], dtype=int64)

# %% [markdown]
# 1. There are 96 rows and 4 columns present in our data
# 2. Data types are also as expected of columns
# 3. We don't have any null values so there is no need to deal with missing values
#
# Now to look at the __Statiscal Summary__ of our data to look at the:
# 1. Number of Unique Variables for each Categorical Data
# 2. Central Locations: Mean, Median, Mode
# 3. Spread of the Data: Standard Deviation, Minimum, Maximum, Quartiles

# %%
life_expectancy_and_gdp.describe(include = "all")
# Out:
#        Country         Year  Life expectancy at birth (years)           GDP
# count       96    96.000000                         96.000000  9.600000e+01
# unique       6          NaN                               NaN           NaN
# top      Chile          NaN                               NaN           NaN
# freq        16          NaN                               NaN           NaN
# mean       NaN  2007.500000                         72.789583  3.880499e+12
# std        NaN     4.633971                         10.672882  5.197561e+12
# min        NaN  2000.000000                         44.300000  4.415703e+09
# 25%        NaN  2003.750000                         74.475000  1.733018e+11
# 50%        NaN  2007.500000                         76.750000  1.280220e+12
# 75%        NaN  2011.250000                         78.900000  4.067510e+12
# max        NaN  2015.000000                         81.000000  1.810000e+13

# %% [markdown]
# 1. We have total 6 countries
# 2. Year ranges from 2000 to 2015
# 3. Average life expectancy is 72.79 years, with minimum of 44.3 years and maximum of 81 years
# 4. We detect the presence of Outliers in GDP with very high GDP
#
# ### Data Visualizations
#
# __Data Visualization__ is an important component for __Exploratory Data Analysis__ because it allows the Analyst to:
# 1. Look at the distribution of Data
# 2. Understand the relationship between variables
# 3. Find the pattern (if present) in the Data
#
# and a many of other questions can be answered through __Data Visualization__
#
# __Life Expectancy over the Years by Countries__

# %%
plt.figure(figsize = (15, 4))
sns.color_palette("bright")

sns.lineplot(data = life_expectancy_and_gdp, x = "Year", y = "Life expectancy at birth (years)", hue = "Country")
plt.legend(bbox_to_anchor = (1.02, 0.7))
plt.show()
plt.clf()

# %% [markdown]
# Except for Zimbabwe all other countries have have life expectancy above 70. Now we compare the GDP of each country.
#
# __GDP over the Year by Countries__

# %%
plt.figure(figsize = (15, 4))
sns.color_palette("bright")

sns.lineplot(data = life_expectancy_and_gdp, x = "Year", y = "GDP", hue = "Country")
plt.legend(bbox_to_anchor = (1.02, 0.7))
plt.show()
plt.clf()

# %% [markdown]
# __Life Expectancy and GDP for China__

# %%
data = life_expectancy_and_gdp[['Life expectancy at birth (years)', 'GDP']][life_expectancy_and_gdp['Country'] == "China"].reset_index(drop = True)

sns.lmplot(x = "GDP", y = "Life expectancy at birth (years)", data = data, line_kws={'color': 'black'}, lowess=True, height = 4, aspect = 15/4)
plt.show()
plt.clf()
